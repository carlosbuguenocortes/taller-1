# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosbuguenocortes/taller-1/blob/main/Taller_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve()))

# %%
# !ls -R /content/| head -200
# Out:
# /content/:
# drive
# sample_data
#
# /content/drive:
# MyDrive
# Shareddrives
#
# /content/drive/MyDrive:
# 06-12-2025 19.31.m4a
# 5.py
# 6.py
# AAAAA.py
# Alfa Centauri Descarga
# ALUMNO REGULAR CANTÓN DE RECLUTAMIENTO-CONSTANTINO DEMÓSTENES BEKIOS CANALES.pdf
# Apuntes cap6.gdoc
# Arquitectura Taller1.gdoc
# asdasd
# BALATRINO
# borrador conclusiones coe2 (1).pdf
# borrador conclusiones coe2 (2).pdf
# borrador conclusiones coe2.pdf
# calculoopromedio1.psc
# calculoopromedio2.psc
# Ciclo del cobre.gdoc
# circooper2.pdf
# Colab Notebooks
# diagrama clases.drawio.pdf
# diagrama de clases.drawio.png
# Documento sin títINfformoeulo.gdoc
# Documento sin título (1).gdoc
# Documento sin título (2).gdoc
# Documento sin título (3).gdoc
# Documento sin título.gdoc
# Documento sin título.pdf
# dominio.drawio.pdf
# ejercicio5.py
# El arte como una forma de escapismo: La música de Devon Hendryx y el retrato emocional que ilustra.gdoc
# Equidad genero apuntes.gdoc
# ...

# %% [markdown]
# nuevo desde sample_data

# %%
# %cd /content/sample_data/template/src
# Out:
# [Errno 2] No such file or directory: '/content/sample_data/template/src'
# /content/sample_data

# %%
# %cd /content/sample_data
# Out:
# /content/sample_data

# %%
# !python main.py
# Out:
# python3: can't open file '/content/sample_data/main.py': [Errno 2] No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python main.py
# Out:
# python3: can't open file '/content/sample_data/main.py': [Errno 2] No such file or directory

# %% [markdown]
# n

# %%
# !find /content/sample_data -name "main.py"
# Out:
# /content/sample_data/wikipedia_grafos/wikipedia-grafos/content/sample_data/template/src/main.py

# %%
# %cd /content/sample_data/template/src
# Out:
# [Errno 2] No such file or directory: '/content/sample_data/template/src'
# /content/sample_data

# %%
# %cd /content/sample_data/wikipedia_grafos/wikipedia-grafos/content/sample_data/template/src
# Out:
# /content/sample_data/wikipedia_grafos/wikipedia-grafos/content/sample_data/template/src

# %%
# !python main.py
# Out:
# Resumen del grafo
# -----------------
# Cantidad de articulos: 5000
# Cantidad de enlaces: 2419
#
# Top 10 por grado de entrada
# ---------------------------
# 1. Buprestidae -> 548
# 2. Buprestoidea -> 536
# 3. Adrian Monk -> 17
# 4. Natalie Teeger -> 16
# 5. Randy Disher -> 15
# 6. Traylor Howard -> 14
# 7. Leland Stottlemeyer -> 14
# 8. Jason Gray-Stanford -> 11
# 9. Lee Goldberg -> 10
# 10. Buddy Buie -> 9
#
# Top 10 por grado de salida
# --------------------------
# 1. Agrilinae -> 199
# 2. Buprestinae -> 137
# 3. Chrysochroinae -> 108
# 4. Polycestinae -> 83
# 5. Buprestidae -> 50
# 6. List of Missouri highways -> 28
# 7. List of beetles of Great Britain -> 27
# 8. Natalie Teeger -> 15
# 9. Mr. Monk and the Two Assistants -> 14
# 10. Mr. Monk and the Dirty Cop -> 13
#
# Archivos generados:
# /content/sample_data/wikipedia_grafos/wikipedia-grafos/content/sample_data/template/results/reporte_basico.txt
#
# Siguientes pasos sugeridos:
# Completar analisis de BFS y DFS.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
# 'Acta de reunión 2 Proyecto.gdoc'
# 'Ayudantía 16-01.pdf'
# 'Ayudantía 21-01.gdoc'
# 'Ayudantía 21-01.pdf'
# 'Carta Gantt Parking Bros.xlsx'
#  Classroom
# 'codigo funcionando.gdoc'
# 'Colab Notebooks'
# 'Copia de Prueba 1.gdoc'
# 'curriculo 1 (1).gdoc'
# 'curriculo 1 (2).gdoc'
# 'curriculo 1 (3).gdoc'
# 'curriculo 1.gdoc'
# 'Diagrama Taller1'
# 'Discurso venta ParkingBros.gdoc'
# 'Documento sin título (1).gdoc'
# 'Documento sin título (2).gdoc'
# 'Documento sin título (3).gdoc'
# 'Documento sin título (4).gdoc'
# 'Documento sin título.gdoc'
# 'Estadística Códigos en R'
# 'Guía Simulación para fuerza(1).docx'
# 'Hoja de cálculo sin título (1).gsheet'
# 'Hoja de cálculo sin título.gsheet'
# 'Informe gases y estequiometría.docx'
# 'Informe_Laboratorio_Quimica General_ICI_2023 (Soluciones Quimicas).docx'
#  IO2.xlsx
# 'Pack Pruebas 2.zip'
# 'proga asisna.py'
# 'Semana 4 carlos.gdoc'
# 'Tutoría 8 (Matrices).zip'

# %%
# !mkdir -p /content/drive/MyDrive/wikipedia_grafos

# %%
# !cp -r /content/sample_data/wikipedia_grafos/wikipedia-grafos/content/sample_data/template /content/drive/MyDrive/wikipedia_grafos/

# %%
# !ls /content/drive/MyDrive/wikipedia_grafos
# Out:
# template

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/wikipedia_grafos/template/src
# Out:
# /content/drive/MyDrive/wikipedia_grafos/template/src

# %%
# !python main.py
# Out:
# Resumen del grafo
# -----------------
# Cantidad de articulos: 5000
# Cantidad de enlaces: 2419
#
# Top 10 por grado de entrada
# ---------------------------
# 1. Buprestidae -> 548
# 2. Buprestoidea -> 536
# 3. Adrian Monk -> 17
# 4. Natalie Teeger -> 16
# 5. Randy Disher -> 15
# 6. Traylor Howard -> 14
# 7. Leland Stottlemeyer -> 14
# 8. Jason Gray-Stanford -> 11
# 9. Lee Goldberg -> 10
# 10. Buddy Buie -> 9
#
# Top 10 por grado de salida
# --------------------------
# 1. Agrilinae -> 199
# 2. Buprestinae -> 137
# 3. Chrysochroinae -> 108
# 4. Polycestinae -> 83
# 5. Buprestidae -> 50
# 6. List of Missouri highways -> 28
# 7. List of beetles of Great Britain -> 27
# 8. Natalie Teeger -> 15
# 9. Mr. Monk and the Two Assistants -> 14
# 10. Mr. Monk and the Dirty Cop -> 13
#
# Archivos generados:
# /content/drive/MyDrive/wikipedia_grafos/template/results/reporte_basico.txt
#
# Siguientes pasos sugeridos:
# Completar analisis de BFS y DFS.
# Implementar PageRank y exportar resultados.
# ...
